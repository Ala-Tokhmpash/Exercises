# %%
import numpy as np 
import pandas as pd

# %%
file = "../../Data/titanic.csv"

# %%
file = "/Users/ala/Documents/Data/titanic.csv"

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 5           0       3                                    Mr. James Moran
# 6           0       1                             Mr. Timothy J McCarthy
# 7           0       3                      Master. Gosta Leonard Palsson
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10          1       3                     Miss. Marguerite Rut Sandstrom
# 11          1       1                            Miss. Elizabeth Bonnell
# ...

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df[(df['Pclass'] == 3) | (df['Pclass'] == 2) ]
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 2           1       3                              Miss. Laina Heikkinen
# 4           0       3                            Mr. William Henry Allen
# 5           0       3                                    Mr. James Moran
# 7           0       3                      Master. Gosta Leonard Palsson
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10          1       3                     Miss. Marguerite Rut Sandstrom
# 12          0       3                      Mr. William Henry Saundercock
# 13          0       3                         Mr. Anders Johan Andersson
# 14          0       3                Miss. Hulda Amanda Adolfina Vestrom
# 15          1       2                     Mrs. (Mary D Kingcome) Hewlett
# ...

# %%
# %timeit df[(df['Pclass'] == 3) | (df['Pclass'] == 2) ]
# Out:
# 833 µs ± 36.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit df.query('Pclass in [2,3]')
# Out:
# 1.2 ms ± 35.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
a = df 
c = [2,3]
b= a.query('Pclass in {}'.format(c))
# Out:
# 1.35 ms ± 90.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit df[df['Pclass'].isin([2,3])]
# Out:
# 512 µs ± 18.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
from sklearn.datasets import california_housing

# %%
c = california_housing.fetch_california_housing()

# %%
pd.DataFrame(c.data)
# Out:
#             0     1         2         3       4         5      6       7
# 0      8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1      8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2      7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3      5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4      3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25
# 5      4.0368  52.0  4.761658  1.103627   413.0  2.139896  37.85 -122.25
# 6      3.6591  52.0  4.931907  0.951362  1094.0  2.128405  37.84 -122.25
# 7      3.1200  52.0  4.797527  1.061824  1157.0  1.788253  37.84 -122.25
# 8      2.0804  42.0  4.294118  1.117647  1206.0  2.026891  37.84 -122.26
# 9      3.6912  52.0  4.970588  0.990196  1551.0  2.172269  37.84 -122.25
# 10     3.2031  52.0  5.477612  1.079602   910.0  2.263682  37.85 -122.26
# 11     3.2705  52.0  4.772480  1.024523  1504.0  2.049046  37.85 -122.26
# ...
