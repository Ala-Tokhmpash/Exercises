# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# This is going to be my first attempt at DS!

# %%
path_to_data = "../../Data/"
cheat = "/Users/ala/Documents/Data/titanic.csv"

# %%
df = pd.read_csv(path_to_data + "titanic.csv")

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 5           0       3                                    Mr. James Moran
# 6           0       1                             Mr. Timothy J McCarthy
# 7           0       3                      Master. Gosta Leonard Palsson
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10          1       3                     Miss. Marguerite Rut Sandstrom
# 11          1       1                            Miss. Elizabeth Bonnell
# ...

# %%
df.shape
# Out:
# (887, 8)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %%
df["Fare"].mean()
# Out:
# 32.30542018038328

# %%
df.groupby(["Pclass"])["Fare"].describe()
# Out:
#         count       mean        std  min       25%      50%   75%       max
# Pclass
# 1       216.0  84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       184.0  20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       487.0  13.707707  11.817309  0.0   7.75000   8.0500  15.5   69.5500

# %%
gb = df.groupby(['Sex'])

# %%
gb.groups
# Out:
# {'female': Int64Index([  1,   2,   3,   8,   9,  10,  11,  14,  15,  18,
#              ...
#              862, 867, 870, 871, 875, 876, 878, 881, 883, 884],
#             dtype='int64', length=314),
#  'male': Int64Index([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,
#              ...
#              869, 872, 873, 874, 877, 879, 880, 882, 885, 886],
#             dtype='int64', length=573)}

# %%
gb.sum()
# Out:
#         Survived  Pclass       Age  Siblings/Spouses Aboard  \
# Sex
# female       233     678   8704.00                      218
# male         109    1367  17437.17                      248
#
#         Parents/Children Aboard        Fare
# Sex
# female                      204  13966.6628
# male                        136  14688.2449

# %%
df.index
# Out:
# RangeIndex(start=0, stop=887, step=1)

# %%
def z_score(l, asghar, std):
#     mean = np.mean(l)
#     std = np.std(l)
    return (l - asghar)/std

# %%
m = df["Fare"].mean()
std = df['Fare'].std()

# %%
from functools import partial

# %%
z_score(df['Fare'],m,std)
# Out:
# 0     -0.503302
# 1      0.782971
# 2     -0.489743
# 3      0.417712
# 4     -0.487232
# 5     -0.479031
# 6      0.392854
# 7     -0.225592
# 8     -0.425296
# 9     -0.044888
# 10    -0.313475
# 11    -0.115612
# 12    -0.487232
# 13    -0.020699
# 14    -0.491165
# 15    -0.327536
# 16    -0.063887
# 17    -0.387799
# 18    -0.287361
# 19    -0.503805
# 20    -0.126661
# 21    -0.387799
# 22    -0.487650
# 23     0.064171
# 24    -0.225592
# 25    -0.018439
# 26    -0.503805
# 27     4.634092
# 28    -0.490663
# 29    -0.490330
#          ...
# 857   -0.417930
# 858   -0.128083
# 859    0.748153
# 860   -0.387799
# 861   -0.387799
# 862   -0.370558
# 863    0.365400
# 864   -0.458105
# 865   -0.425296
# 866   -0.490330
# 867    0.406749
# 868   -0.548499
# 869   -0.468149
# 870   -0.166836
# 871   -0.503805
# 872   -0.451159
# 873   -0.490330
# 874   -0.490330
# 875    1.021511
# 876   -0.126661
# 877   -0.490330
# 878   -0.437682
# 879   -0.438018
# 880   -0.507320
# ...

# %%
def mult(a,b):
    return a*b

# %%
mult(2,3)
# Out:
# 6

# %%
m_p = partial(mult, 3)

# %%
m_p(2)
# Out:
# 6

# %%
m_p(5)
# Out:
# 15

# %%
z_score_func = partial(z_score, asghar=m, std=std)

# %%
df['Fare'].apply(z_score_func)
# Out:
# 0     -0.503302
# 1      0.782971
# 2     -0.489743
# 3      0.417712
# 4     -0.487232
# 5     -0.479031
# 6      0.392854
# 7     -0.225592
# 8     -0.425296
# 9     -0.044888
# 10    -0.313475
# 11    -0.115612
# 12    -0.487232
# 13    -0.020699
# 14    -0.491165
# 15    -0.327536
# 16    -0.063887
# 17    -0.387799
# 18    -0.287361
# 19    -0.503805
# 20    -0.126661
# 21    -0.387799
# 22    -0.487650
# 23     0.064171
# 24    -0.225592
# 25    -0.018439
# 26    -0.503805
# 27     4.634092
# 28    -0.490663
# 29    -0.490330
#          ...
# 857   -0.417930
# 858   -0.128083
# 859    0.748153
# 860   -0.387799
# 861   -0.387799
# 862   -0.370558
# 863    0.365400
# 864   -0.458105
# 865   -0.425296
# 866   -0.490330
# 867    0.406749
# 868   -0.548499
# 869   -0.468149
# 870   -0.166836
# 871   -0.503805
# 872   -0.451159
# 873   -0.490330
# 874   -0.490330
# 875    1.021511
# 876   -0.126661
# 877   -0.490330
# 878   -0.437682
# 879   -0.438018
# 880   -0.507320
# ...

# %%
df['Fare'].apply(lambda x: (x-m)/std)
# Out:
# 0     -0.503302
# 1      0.782971
# 2     -0.489743
# 3      0.417712
# 4     -0.487232
# 5     -0.479031
# 6      0.392854
# 7     -0.225592
# 8     -0.425296
# 9     -0.044888
# 10    -0.313475
# 11    -0.115612
# 12    -0.487232
# 13    -0.020699
# 14    -0.491165
# 15    -0.327536
# 16    -0.063887
# 17    -0.387799
# 18    -0.287361
# 19    -0.503805
# 20    -0.126661
# 21    -0.387799
# 22    -0.487650
# 23     0.064171
# 24    -0.225592
# 25    -0.018439
# 26    -0.503805
# 27     4.634092
# 28    -0.490663
# 29    -0.490330
#          ...
# 857   -0.417930
# 858   -0.128083
# 859    0.748153
# 860   -0.387799
# 861   -0.387799
# 862   -0.370558
# 863    0.365400
# 864   -0.458105
# 865   -0.425296
# 866   -0.490330
# 867    0.406749
# 868   -0.548499
# 869   -0.468149
# 870   -0.166836
# 871   -0.503805
# 872   -0.451159
# 873   -0.490330
# 874   -0.490330
# 875    1.021511
# 876   -0.126661
# 877   -0.490330
# 878   -0.437682
# 879   -0.438018
# 880   -0.507320
# ...

# %%
(df["Fare"] - df['Fare'].mean() )/df['Fare'].std()
# Out:
# 0     -0.503302
# 1      0.782971
# 2     -0.489743
# 3      0.417712
# 4     -0.487232
# 5     -0.479031
# 6      0.392854
# 7     -0.225592
# 8     -0.425296
# 9     -0.044888
# 10    -0.313475
# 11    -0.115612
# 12    -0.487232
# 13    -0.020699
# 14    -0.491165
# 15    -0.327536
# 16    -0.063887
# 17    -0.387799
# 18    -0.287361
# 19    -0.503805
# 20    -0.126661
# 21    -0.387799
# 22    -0.487650
# 23     0.064171
# 24    -0.225592
# 25    -0.018439
# 26    -0.503805
# 27     4.634092
# 28    -0.490663
# 29    -0.490330
#          ...
# 857   -0.417930
# 858   -0.128083
# 859    0.748153
# 860   -0.387799
# 861   -0.387799
# 862   -0.370558
# 863    0.365400
# 864   -0.458105
# 865   -0.425296
# 866   -0.490330
# 867    0.406749
# 868   -0.548499
# 869   -0.468149
# 870   -0.166836
# 871   -0.503805
# 872   -0.451159
# 873   -0.490330
# 874   -0.490330
# 875    1.021511
# 876   -0.126661
# 877   -0.490330
# 878   -0.437682
# 879   -0.438018
# 880   -0.507320
# ...

# %%
np.mean(df['Fare'])
# Out:
# 32.30542018038328
